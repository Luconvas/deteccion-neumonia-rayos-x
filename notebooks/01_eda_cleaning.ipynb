# %%
# Importar las bibliotecas necesarias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import dask.dataframe as dd

# Cargar los datos utilizando Dask
# Supongamos que los datos están en un directorio llamado 'data/raw'
raw_data_path = 'data/raw/data.csv'

# Ejemplo de carga de datos
df = dd.read_csv(raw_data_path)

# Mostrar la distribución de clases
sns.countplot(data=df.compute(), x='label')
plt.title('Distribución de clases')
plt.show()
# Out:
# Número de imágenes normales en el conjunto de entrenamiento: 1341
# Número de imágenes con neumonía en el conjunto de entrenamiento: 3875
# C:\Users\lcont\AppData\Local\Temp\ipykernel_1944\4294543747.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=categories, y=counts, palette='viridis')
# C:\Users\lcont\AppData\Local\Temp\ipykernel_1944\4294543747.py:96: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=categories, palette='viridis')
# Tamaño del conjunto de entrenamiento (balanceado): 68
# Tamaño del conjunto de validación (balanceado): 17
